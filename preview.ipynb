# %%
import numpy as np
data = np.load("results/eye_to_hand/pnp_debug/pnp_001.npz")
print(data.files)
print(data['objp'])
# Out:
# ['objp', 'corners_2d', 'camera_pose']
# [[0.    0.    0.   ]
#  [0.006 0.    0.   ]
#  [0.012 0.    0.   ]
#  [0.018 0.    0.   ]
#  [0.024 0.    0.   ]
#  [0.03  0.    0.   ]
#  [0.036 0.    0.   ]
#  [0.042 0.    0.   ]
#  [0.048 0.    0.   ]
#  [0.054 0.    0.   ]
#  [0.06  0.    0.   ]
#  [0.    0.006 0.   ]
#  [0.006 0.006 0.   ]
#  [0.012 0.006 0.   ]
#  [0.018 0.006 0.   ]
#  [0.024 0.006 0.   ]
#  [0.03  0.006 0.   ]
#  [0.036 0.006 0.   ]
#  [0.042 0.006 0.   ]
#  [0.048 0.006 0.   ]
#  [0.054 0.006 0.   ]
#  [0.06  0.006 0.   ]
#  [0.    0.012 0.   ]
#  [0.006 0.012 0.   ]
#  [0.012 0.012 0.   ]
#  [0.018 0.012 0.   ]
#  [0.024 0.012 0.   ]
#  [0.03  0.012 0.   ]
#  [0.036 0.012 0.   ]
#  [0.042 0.012 0.   ]
#  [0.048 0.012 0.   ]
#  [0.054 0.012 0.   ]
#  [0.06  0.012 0.   ]
#  [0.    0.018 0.   ]
#  [0.006 0.018 0.   ]
#  [0.012 0.018 0.   ]
#  [0.018 0.018 0.   ]
#  [0.024 0.018 0.   ]
#  [0.03  0.018 0.   ]
#  [0.036 0.018 0.   ]
#  [0.042 0.018 0.   ]
# ...

# %%
print(data['corners_2d'])
# Out:
# [[ 924.998      70.487816]
#  [ 940.9144     76.55458 ]
#  [ 956.0867     82.60006 ]
#  [ 971.21       88.505226]
#  [ 985.69147    94.15173 ]
#  [1000.2588     99.59485 ]
#  [1014.2692    105.06355 ]
#  [1027.9772    110.47225 ]
#  [1041.436     115.603546]
#  [1054.7006    120.88167 ]
#  [1067.7454    125.57563 ]
#  [ 913.9556     91.54184 ]
#  [ 929.3421     97.48606 ]
#  [ 944.52875   103.22806 ]
#  [ 959.58215   108.543755]
#  [ 974.21576   114.009926]
#  [ 988.5152    119.19593 ]
#  [1002.32983   124.47631 ]
#  [1016.2506    129.2467  ]
#  [1029.4354    134.37901 ]
#  [1042.5055    139.15675 ]
#  [1055.3116    143.92903 ]
#  [ 903.04425   111.85857 ]
#  [ 918.4911    117.42096 ]
#  [ 933.6258    122.49777 ]
#  [ 948.4598    127.82336 ]
#  [ 963.0458    133.05357 ]
#  [ 977.10657   138.23575 ]
#  [ 991.0005    142.96037 ]
#  [1004.48285   147.55692 ]
#  [1017.63837   152.39737 ]
#  [1030.7638    157.02818 ]
#  [1043.449     161.4518  ]
#  [ 892.6171    131.49619 ]
# ...
